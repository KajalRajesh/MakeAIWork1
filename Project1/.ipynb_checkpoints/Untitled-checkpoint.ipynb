# %%
import requests
import pandas as pd

# %%
df2 = pd.read_csv('../projects/Project1/hospitaldata.csv',',')
display(df2)
# Out:
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_25400\2120737810.py:1: FutureWarning: In a future version of pandas all arguments of read_csv except for the argument 'filepath_or_buffer' will be keyword-only.
#   df2 = pd.read_csv('../projects/Project1/hospitaldata.csv',',')
#         id  genetic  length  mass  exercise  smoking  alcohol  sugar  lifespan
# 0        1     84.0   180.0  90.0       2.0      9.0      1.0      2        86
# 1        2     84.0   204.0  79.0       3.0      2.0      7.0      3       100
# 2        3     84.0   174.0  74.0       3.0     20.0      3.0      2        87
# 3        4     84.0   187.0  78.0       2.0      6.0      5.0      3        91
# 4        5     84.0   187.0  89.0       2.0     12.0      0.0      2        83
# ...    ...      ...     ...   ...       ...      ...      ...    ...       ...
# 8187  8188     82.0   185.0  67.0       3.0     11.0      8.0      2        90
# ...

# %%
Q1=df2.quantile(0.25)
Q3=df2.quantile(0.75)
IQR = Q3 - Q1
print(Q1)
print(Q3)
print(IQR)

df2 =df2[~((df2<(Q1-1.5*IQR)) | (df2>(Q3+1.5*IQR))).any(axis=1)]
display(df2)
# Out:
# id          2048.75
# genetic       79.00
# length       174.00
# mass          70.00
# exercise       1.00
# smoking        3.00
# alcohol        4.00
# sugar          2.00
# lifespan      68.00
# Name: 0.25, dtype: float64
# id          6144.25
# genetic       81.00
# length       193.00
# mass          88.00
# exercise       2.00
# smoking       16.00
# alcohol        8.00
# sugar          3.00
# lifespan      83.00
# Name: 0.75, dtype: float64
# id          4095.5
# genetic        2.0
# length        19.0
# mass          18.0
# exercise       1.0
# smoking       13.0
# alcohol        4.0
# sugar          1.0
# lifespan      15.0
# dtype: float64
