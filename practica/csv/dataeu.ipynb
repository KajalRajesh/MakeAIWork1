# %%
import pandas as pd
from IPython.display import display, HTML
import matplotlib.pyplot as plt%matplotlib inline

# %%
folder_name ="C:/Users/Lenovo/MakeAIWork1/practica/data/Export-JRC-Data-Catalogue.xls"
df_newdata= pd.read_excel(folder_name, usecols ='A, B, D, F, M, J, T, U')
#show_newdata(df_newdata)
sort_newdata = df_newdata.sort_values(['Start Year'], ascending = False)
display(sort_newdata)
sort_newdata['Start Year'].plot(kind = "barh")
#df =df_newdata[['Name','Process Type']]
#display(df)
# Out:
#       ID                                               Name  \
# 685  686  INPS project in the UNESCO World Top 10 for ar...
# 137  138    Maxi - Chatbot answering questions on insurance
# 411  412          Chatbot SAM - Virtual Community Assistant
# 306  307  AI for fisheries inspections - Detecting illeg...
# 307  308                          AIDA: AI Disaster Advisor
# ..   ...                                                ...
# 456  457  Detect early learning problems in primary scho...
# 454  455  AI in e-Sociala program - Optimization of the ...
# 607  608  FIRST - A Flexible Interactive Reading Support...
# 343  344                                       iRN_iColumbo
# 123  124                            Robotic System Da Vinci
#
#                                            Description  \
# 685  The plan to make the communication flow of mil...
# 137  The Social Insurance Aargau SVA has introduced...
# 411  Chatbot SAM is a solution that will be introdu...
# ...

# %%
show_newdata(df_newdata)
